# %% [markdown]
#     ACTIVIDAD FORO 2 - EJERCICIO OPERADOR TERNARIO
#     FORO DE EXPERIENCIA
#     Presentado por: Fabian Rosero
#     Ejecutor: Miguel Guerrero.

# %% [markdown]
#     Solictar un dato por teclado el cual sera almacenado en la variable precio.
#     Validar que ese dato ingresado sea tipo numerico especificamente float (isdigit , con conversión de tipo)
#     validar si el precio esta en uno de los siguientes rangos (con operador ternario)
#
#      > 10000 - <= 50000
#      > 50000 - <= 100000
#      > 100000 - <= 200000
#      > 200000
#
# Segun el rango imprimir un mensaje informando en que rango esta el valor ingresado.
# El mensaje del rango en el cual se encuentra debe ser almacenado en la variable mensaje.
# Exitos.

# %%
precio = input('Favor digitar un precio')
if precio.isdigit():
    
    precio = float(precio)
    mensaje = 'El rango esta entre 10001 y 50000' if 10000< precio <=50000 else 'El rango esta entre 50001 y 100000' if 50000 < precio <= 100000 else 'El rango esta entre 100001 y 200000' if 100000 < precio <= 200000 else "El rango es mayor a 200001" if precio >200000 else "El rango es menor a 10001"
    print(mensaje)
else:
        print("Favor Ingrese solo numeros.")
# Out:
# El rango esta entre 10001 y 50000
